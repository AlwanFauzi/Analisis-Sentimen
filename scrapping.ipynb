# %%
# !pip install google-play-scraper
# Out:
# Requirement already satisfied: google-play-scraper in c:\users\user\anaconda3\envs\sentimenvenv\lib\site-packages (1.2.7)

# %%
from google_play_scraper import app, reviews, Sort, reviews_all

# %%
import pandas as pd  # Pandas untuk manipulasi dan analisis data
pd.options.mode.chained_assignment = None  # Menonaktifkan peringatan chaining
import numpy as np  # NumPy untuk komputasi numerik

# %%
from google_play_scraper import Sort, reviews

# Mengambil ulasan
result, continuation_token = reviews(
    'com.ruangguru.livestudents',  
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=30000
)

df_busu = pd.DataFrame(result)

# %%
df_busu
# Out:
#                                    reviewId         userName  \
# 0      bff33017-f4fb-4f34-b9e9-0086e8a7627d  Pengguna Google
# 1      744c3a13-91f4-471a-8f5f-27b458b9cc81  Pengguna Google
# 2      1c2d93da-7903-4b67-a01e-d99365037596  Pengguna Google
# 3      6aeb166d-fec8-49a1-bd3b-1da8ba591a95  Pengguna Google
# 4      89767630-23ef-491f-b4fa-7db002ac85c8  Pengguna Google
# ...                                     ...              ...
# 29995  08c91ba5-ff5e-464b-9cd6-d349fd39a782  Pengguna Google
# 29996  417b0ad1-f1e5-4c35-8446-0b7031682bbe  Pengguna Google
# 29997  1872bdbe-5888-462f-bc17-bed405234bba  Pengguna Google
# 29998  513d9f1b-b151-4c0f-a0ee-c4cb0d807f58  Pengguna Google
# 29999  9975a332-9ef6-45ef-adbe-e0e51d8f6dd7  Pengguna Google
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/EGemoI2N...
# 1      https://play-lh.googleusercontent.com/EGemoI2N...
# 2      https://play-lh.googleusercontent.com/EGemoI2N...
# 3      https://play-lh.googleusercontent.com/EGemoI2N...
# 4      https://play-lh.googleusercontent.com/EGemoI2N...
# ...                                                  ...
# 29995  https://play-lh.googleusercontent.com/EGemoI2N...
# 29996  https://play-lh.googleusercontent.com/EGemoI2N...
# 29997  https://play-lh.googleusercontent.com/EGemoI2N...
# 29998  https://play-lh.googleusercontent.com/EGemoI2N...
# 29999  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                  content  score  \
# 0      semuanya yg ada di ruang guru sangat bagus tet...      3
# 1      saya lagi nonton video pembelajaran nih, diman...      3
# 2      bagus banget nih buat belajar, untuk sekarang ...      5
# 3      Overall semuanya tampak bagus, tapi tolong dev...      5
# 4      ruangguru benar² menjadi ruang yang menyenangk...      5
# ...                                                  ...    ...
# 29995  mendapatkan sebuah pelajaran yang lebih efekti...      5
# 29996  Aplikasi ini membuat saya semakin ngerti tenta...      5
# 29997  yey bisa belajar lagi asah otak lagi guys tapi...      5
# 29998  aplikasi ini bagus sangat ber prestasi da sela...      5
# 29999  Ruangguru sangat bermanfaat sekali untuk saya ...      4
#
#        thumbsUpCount reviewCreatedVersion                  at  \
# 0                  7               6.95.0 2025-04-11 20:41:01
# 1                  4               6.94.1 2025-04-05 18:22:46
# 2                 28               6.94.1 2025-04-23 15:03:44
# 3                217               6.94.1 2025-03-04 15:54:12
# 4                192               6.94.0 2025-02-17 15:50:39
# ...              ...                  ...                 ...
# 29995              0                3.2.1 2019-01-14 22:29:03
# 29996              0                4.6.4 2019-08-31 17:47:27
# 29997              0                4.5.3 2019-08-04 22:27:59
# 29998              0                4.5.3 2019-07-19 22:01:38
# 29999              0                5.1.2 2020-03-24 06:26:20
#
#                                             replyContent           repliedAt  \
# 0      Maaf ya bikin Sundari Saragih nggak nyaman. Un... 2025-04-12 18:49:06
# 1      Maaf ya bikin Rhamdan nggak nyaman. Untuk bant... 2025-04-06 10:23:00
# 2      Makasih ya rating bintang 5-nya Alzajira. Sene... 2025-04-23 16:14:10
# 3      Terima kasih ya atas saran dan masukannya. Sar... 2025-03-04 16:07:18
# 4      Makasih ya Imamm buat bintang 5-nya. Seneng de... 2025-02-17 16:48:34
# ...                                                  ...                 ...
# 29995  Hai.\nTerima kasih sudah memberi bintang 5 unt... 2019-01-15 07:34:57
# 29996  Hai Fikar, makasi buat review dan apresiasinya... 2019-11-01 10:19:56
# 29997  Hai, terima kasih sudah mendownload Aplikasi R... 2019-08-05 17:06:44
# 29998  Hai Bayu. \nTerimakasih banyak yaa untuk dukun... 2019-08-17 14:41:30
# 29999  Hai, terima kasih telah memilih Aplikasi Ruang... 2020-03-24 10:43:49
#
#       appVersion
# 0         6.95.0
# 1         6.94.1
# 2         6.94.1
# 3         6.94.1
# 4         6.94.0
# ...          ...
# 29995      3.2.1
# 29996      4.6.4
# 29997      4.5.3
# 29998      4.5.3
# 29999      5.1.2
#
# [30000 rows x 11 columns]

# %%
# Membuat DataFrame baru (clean_df) dengan menghapus baris yang memiliki nilai yang hilang (NaN) dari app_reviews_df
clean_df = df_busu.dropna()

# %%
clean_df = clean_df.drop_duplicates()

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21591 entries, 0 to 29999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              21591 non-null  object
#  1   userName              21591 non-null  object
#  2   userImage             21591 non-null  object
#  3   content               21591 non-null  object
#  4   score                 21591 non-null  int64
#  5   thumbsUpCount         21591 non-null  int64
#  6   reviewCreatedVersion  21591 non-null  object
#  7   at                    21591 non-null  datetime64[ns]
#  8   replyContent          21591 non-null  object
#  9   repliedAt             21591 non-null  datetime64[ns]
#  10  appVersion            21591 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 2.0+ MB

# %%
df_fix = clean_df['content']
df_fix
# Out:
# 0        semuanya yg ada di ruang guru sangat bagus tet...
# 1        saya lagi nonton video pembelajaran nih, diman...
# 2        bagus banget nih buat belajar, untuk sekarang ...
# 3        Overall semuanya tampak bagus, tapi tolong dev...
# 4        ruangguru benar² menjadi ruang yang menyenangk...
#                                ...
# 29995    mendapatkan sebuah pelajaran yang lebih efekti...
# 29996    Aplikasi ini membuat saya semakin ngerti tenta...
# 29997    yey bisa belajar lagi asah otak lagi guys tapi...
# 29998    aplikasi ini bagus sangat ber prestasi da sela...
# 29999    Ruangguru sangat bermanfaat sekali untuk saya ...
# Name: content, Length: 21591, dtype: object

# %%
# Menyimpan ke CSV
df_fix.to_csv("ruangguru_review.csv", index=False)
